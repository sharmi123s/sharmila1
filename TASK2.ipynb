# %%
import pandas as pd

# %%
import numpy as np

# %%
import pickle

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
import imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,f1_score

# %% [markdown]
# data=pd.read_csv(r"/content/Admission_Predict.csv")

# %%
data.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-bf0ee425fdba> in <cell line: 1>()
# ----> 1 data.info
#
# NameError: name 'data' is not defined

# %%
data.SOP = pd.to_numeric(data.SOP, errors ='coerce')
data.isnull().any()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-f88e7dafe81d> in <cell line: 1>()
# ----> 1 data.SOP = pd.to_numeric(data.SOP, errors ='coerce')
#       2 data.isnull().any()
#
# NameError: name 'data' is not defined

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data["Serial No."] = le.fit_transform(data["Serial No."])
data["GRE Score"] = le.fit_transform(data["GRE Score"])
data["TOEFL Score"] = le.fit_transform(data["TOEFL Score"])
data["University Rating"] = le.fit_transform(data["University Rating"])
data["SOP"] = le.fit_transform(data["SOP"])
data["LOR "] = le.fit_transform(data["LOR "])
data["CGPA"] = le.fit_transform(data["CGPA"])
data["Research"] = le.fit_transform(data["Research"])
data["Chance of Admit "] = le.fit_transform(data["Chance of Admit "])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-dc349c801ddf> in <cell line: 3>()
#       1 from sklearn.preprocessing import LabelEncoder
#       2 le = LabelEncoder()
# ----> 3 data["Serial No."] = le.fit_transform(data["Serial No."])
#       4 data["GRE Score"] = le.fit_transform(data["GRE Score"])
#       5 data["TOEFL Score"] = le.fit_transform(data["TOEFL Score"])
#
# NameError: name 'data' is not defined

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-304fa4ce4ebd> in <cell line: 1>()
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
x=data.iloc[:,0:19].values
y=data.iloc[:,19:20].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-6482e04de487> in <cell line: 1>()
# ----> 1 x=data.iloc[:,0:19].values
#       2 y=data.iloc[:,19:20].values
#
# NameError: name 'data' is not defined

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-6fcf9dfbd479> in <cell line: 1>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-9063a9f0e032> in <cell line: 1>()
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
data.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-2bb0b18689d4> in <cell line: 1>()
# ----> 1 data.describe()
#
# NameError: name 'data' is not defined

# %%
sns.distplot(data['GRE Score'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-64e93544a305> in <cell line: 1>()
# ----> 1 sns.distplot(data['GRE Score'])
#
# NameError: name 'data' is not defined

# %%
sns.pairplot(data=data,hue='Research',markers=["^","v"],palette='inferno')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-7fc97eaf1bef> in <cell line: 1>()
# ----> 1 sns.pairplot(data=data,hue='Research',markers=["^","v"],palette='inferno')
#
# NameError: name 'data' is not defined

# %%
sns.scatterplot(x='University Rating',y='CGPA',data=data,color='RED',s=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-58b3654cb785> in <cell line: 1>()
# ----> 1 sns.scatterplot(x='University Rating',y='CGPA',data=data,color='RED',s=100)
#
# NameError: name 'data' is not defined

# %%
category=['GRE Score','TOEFL Score','University Rating','SOP',' LOR','CGPA','Research','Chance of Admit']
color=['yellowgreen','gold','lightskyblue','pink','red','purple','orange','gray']
start=True
for i in np.arange(4):
  fig=plt.figure(figsize=(14,8))
  plt.subplot2grid((4,2),(i,0))
  data[category[2*i]].hist(color=color[2*i],bins=10)
  plt.title(category[2*i])
  plt.subplot2grid((4,2),(i,1))
  data[category[2*i+1]].hist(color=color[2*i+1],bins=10)
  plt.title(category[2*i+1])
plt.subplots_adjust(hspace=0.7,wspace=0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-5ae0d0e36257> in <cell line: 4>()
#       5   fig=plt.figure(figsize=(14,8))
#       6   plt.subplot2grid((4,2),(i,0))
# ----> 7   data[category[2*i]].hist(color=color[2*i],bins=10)
#       8   plt.title(category[2*i])
#       9   plt.subplot2grid((4,2),(i,1))
#
# NameError: name 'data' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
x=sc.fit_transform(x)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-bf56f9a41e46> in <cell line: 3>()
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 sc=MinMaxScaler()
# ----> 3 x=sc.fit_transform(x)
#       4 x
#
# NameError: name 'x' is not defined

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-fd650a055b4b> in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=101)
#
# NameError: name 'x' is not defined

# %%
x=data.iloc[:,0:7].values
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-84930d1aeb39> in <cell line: 1>()
# ----> 1 x=data.iloc[:,0:7].values
#       2 x
#
# NameError: name 'data' is not defined

# %%
y=data.iloc[:,7:].values
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-b3a645eb3ff1> in <cell line: 1>()
# ----> 1 y=data.iloc[:,7:].values
#       2 y
#
# NameError: name 'data' is not defined

# %%
y_train=(y_train>0.5)
y_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-c82d89c690e4> in <cell line: 1>()
# ----> 1 y_train=(y_train>0.5)
#       2 y_train
#
# NameError: name 'y_train' is not defined
